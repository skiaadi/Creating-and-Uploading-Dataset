# %% [markdown]
# <a href="https://colab.research.google.com/github/skiaadi/Creating-and-Uploading-Dataset/blob/main/Exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 10
# ##Create a Dataset and Load Dataset
# ##Aadi Havele
# ##25070123001 ENTC A-1

# %%
import pandas as pd

data = {"Roll_No":[101,102,103,104,105],
        "Gender":["Female","Male","Female","Female","Female"],
        "Department":["CS","Mech","ENTC","Civil","RA"],
        "CGPA":[8.2,9.6,8.0,7.4,8.5]}
d=pd.DataFrame(data)
d.to_csv("students.csv",index=False)
print(d)
# Out:
#    Roll_No  Gender Department  CGPA
# 0      101  Female         CS   8.2
# 1      102    Male       Mech   9.6
# 2      103  Female       ENTC   8.0
# 3      104  Female      Civil   7.4
# 4      105  Female         RA   8.5

# %%
d.shape
# Out:
# (5, 4)

# %%
#Access information of column Department
#Access information of PRN 102
#Find out data type of each column
#Perform mean,median,mode
#Insert a new column grade
#Delete gender column
#CGPA of topper
#CGPA of PRN 105
import pandas as pd
import numpy as np
df=pd.read_csv('/content/Cars93.csv')
print(df)
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25                 NaN
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25                 NaN
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# ...
